# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(rf"/content/amazon_footwear_data_maindata.csv")

# %%
data.head()
# Out:
#       Brand   Gender   Category  Price (₹)  Discount (%)  Rating  Sales Count  \
# 0      Bata  Women's     Sandal      429.0          39.0     4.0          500
# 1     SPARX    Men's     Sandal      629.0          37.0     4.0          800
# 2        XE  Women's      Heels      699.0          72.0     4.0           50
# 3  Centrino    Men's  Flip-Flop      769.0          67.0     3.6            0
# 4     Sparx    Men's   Slippers      279.0          20.0     4.1            1
#
#   Country Water Resistant
# 0   India              NO
# 1   India              NO
# 2   India              NO
# 3   India              NO
# 4   India              NO

# %%
data.Brand.value_counts()
# Out:
# Brand
# DOCTOR      94
# Bata        86
# Puma        52
# Woodland    47
# Mochi       25
#             ..
# Carlton      1
# Aircum       1
# TOR          1
# HOOH         1
# ANDUNE       1
# Name: count, Length: 217, dtype: int64

# %%
data=data[~data['Brand'].isin(['Foot','Women','Men','The','U', 'R',])]  #removing unwanted brands

# %%
# df1=data.Brand.value_counts()

# %%
# df1

# %%
# df1.rename('count1',inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1=df1.to_frame()   #convert the series into a dara frame
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-273-1c7f1b80053a> in <cell line: 0>()
# ----> 1 df1=df1.to_frame()   #convert the series into a dara frame
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
# df1[df1['count1'] >10]

# %%
data.Category=data.Category.str.lower()

# %%
data.Category=data.Category.str.rstrip('s')

# %%
data

# %%
# prompt: mode of gender_cartegory groupby category

l=data.groupby('Category')['Gender_cartegory'].agg(lambda x: x.mode() if not x.mode().empty else None)

# %%
# prompt: use l to update  Gender_cartegory and update only nans
# data['Gender_cartegory'] = data.apply(lambda row: l[row['Category']] if pd.isna(row['Gender_cartegory']) else row['Gender_cartegory'], axis=1)
data['Gender_cartegory'] = data.apply(lambda row: l.get(row['Category'], np.nan) if pd.isna(row['Gender_cartegory']) else row['Gender_cartegory'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 957 entries, 0 to 977
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             957 non-null    object
#  1   Gender_cartegory  948 non-null    object
#  2   Category          938 non-null    object
#  3   Price (₹)         957 non-null    float64
#  4   Discount (%)      949 non-null    float64
#  5   Rating            913 non-null    float64
#  6   Sales Count       957 non-null    int64
#  7   Country           926 non-null    object
#  8   Water Resistant   957 non-null    object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 74.8+ KB

# %%
data.Gender.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-279-7adcbbd03717> in <cell line: 0>()
# ----> 1 data.Gender.unique()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'Gender'

# %%
data.rename(columns={'Gender':'Gender_cartegory'},inplace=True)

# %%
data.Gender_cartegory=data.Gender_cartegory.str.lower()

# %%
data
# Out:
#         Brand Gender_cartegory   Category  Price (₹)  Discount (%)  Rating  \
# 0        Bata          women's     sandal      429.0          39.0     4.0
# 1       SPARX            men's     sandal      629.0          37.0     4.0
# 2          XE          women's       heel      699.0          72.0     4.0
# 3    Centrino            men's  flip-flop      769.0          67.0     3.6
# 4       Sparx            men's    slipper      279.0          20.0     4.1
# ..        ...              ...        ...        ...           ...     ...
# 973     egoss            men's       shoe     3320.0           5.0     4.1
# 974    Clarks            men's       shoe     4249.0          29.0     4.0
# 975       Red            men's       shoe     2875.0          10.0     3.8
# 976    ANDUNE            men's       shoe     2499.0          11.0     3.5
# 977      Bata            men's       shoe     2180.0           5.0     3.9
#
#      Sales Count Country Water Resistant
# ...

# %%
l2=data.groupby('Brand')['Discount (%)'].mean()

# %%
data['Discount (%)'] = data.apply(lambda row: l2.get(row['Brand'], np.nan) if pd.isna(row['Discount (%)']) else row['Discount (%)'], axis=1)

# %%
l3=data.groupby('Brand')['Rating'].mean()

# %%
data['Rating'] = data.apply(lambda row: l3.get(row['Brand'], np.nan) if pd.isna(row['Rating']) else row['Rating'], axis=1)

# %%
l4=data.groupby('Brand')['Country'].agg(lambda x: x.mode()[0] if not x.mode().empty else None)

# %%
data['Country'] = data.apply(lambda row: l3.get(row['Brand'], np.nan) if pd.isna(row['Country']) else row['Country'], axis=1)

# %%
data=data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 924 entries, 0 to 977
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             924 non-null    object
#  1   Gender_cartegory  924 non-null    category
#  2   Category          924 non-null    category
#  3   Price (₹)         924 non-null    float64
#  4   Discount (%)      924 non-null    float32
#  5   Rating            924 non-null    float32
#  6   Sales Count       924 non-null    int32
#  7   Country           910 non-null    object
#  8   Water Resistant   924 non-null    object
# dtypes: category(2), float32(2), float64(1), int32(1), object(3)
# memory usage: 49.3+ KB

# %%
data['Gender_cartegory']=data.Gender_cartegory.astype('category')
# Out:
# <ipython-input-307-376d6dc2f907>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gender_cartegory']=data.Gender_cartegory.astype('category')

# %%
data.describe(include='all')
# Out:
#          Brand Gender_cartegory Category     Price (₹)  Discount (%)  \
# count      910              910      910    910.000000    910.000000
# unique     184                5        8           NaN           NaN
# top     DOCTOR            men's     shoe           NaN           NaN
# freq        92              444      302           NaN           NaN
# mean       NaN              NaN      NaN   1367.487912     47.114811
# std        NaN              NaN      NaN   1310.181979     18.338512
# min        NaN              NaN      NaN    149.000000      1.000000
# 25%        NaN              NaN      NaN    620.250000     33.000000
# 50%        NaN              NaN      NaN    899.000000     49.960785
# 75%        NaN              NaN      NaN   1724.500000     62.000000
# max        NaN              NaN      NaN  13995.000000     85.000000
#
#             Rating  Sales Count Country Water Resistant
# count   910.000000   910.000000     910             910
# ...

# %%
data['Category']=data.Category.astype('category')
# Out:
# <ipython-input-296-c875b1f7f42e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Category']=data.Category.astype('category')

# %%
data['Discount (%)']=data['Discount (%)'].astype('float32')
# Out:
# <ipython-input-300-3f6a1ec59b00>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Discount (%)']=data['Discount (%)'].astype('float32')

# %%
data['Rating']=data['Rating'].astype('float32')
# Out:
# <ipython-input-303-70ae77d49bfa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Rating']=data['Rating'].astype('float32')

# %%
data['Sales Count']=data['Sales Count'].astype('int32')
# Out:
# <ipython-input-305-f72723f170d8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Sales Count']=data['Sales Count'].astype('int32')

# %%
data.Country.unique()
# Out:
# array(['India', 'China', 'Vietnam', 'Indonesia', 3.755555555555555,
#        'Italy', 4.266666666666667, 3.9333333333333336, 2.7,
#        3.682608695652174, 4.1, 3.8, 4.0, 3.770588235294117, 4.3, 2.6,
#        'Thailand', 3.6333333333333333, 5.0, 4.15, 2.4, 3.3], dtype=object)

# %%
data[~data.Country.isin(['India', 'China', 'Vietnam', 'Indonesia',
       'Italy',
      #  'Thailand',])]
# Out:
#   File "<ipython-input-314-e5fae630525e>", line 3
#     #  'Thailand',])]
#                      ^
# SyntaxError: incomplete input

# %%
data['Country'] = data.apply(lambda row: np.nan if row['Country'].isdigit() else row['Country'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-319-2f3cd69a1972> in <cell line: 0>()
# ----> 1 data['Country'] = data.apply(lambda row: np.nan if row['Country'].isdigit() else row['Country'], axis=1)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10372             kwargs=kwargs,
#   10373         )
# > 10374         return op.apply().__finalize__(self, method="apply")
#   10375
#   10376     def map(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#     914             return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
#     915
# --> 916         return self.apply_standard()
#     917
#     918     def agg(self):
#
# ...

# %%
# prompt: if country has float replace it with nan

import numpy as np
# ... (Your existing code)

# Convert numeric strings in 'Country' to NaN
data['Country'] = data['Country'].apply(lambda x: np.nan if isinstance(x, (int, float)) else x)

# %%
data['Country'] = data['Country'].apply(lambda x: np.nan if isinstance(x, (int, float)) else x)
# Out:
# <ipython-input-320-5411c1ac5565>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Country'] = data['Country'].apply(lambda x: np.nan if isinstance(x, (int, float)) else x)

# %%
l5=data.groupby('Brand')['Country'].agg(lambda x: x.mode()[0] if not x.mode().empty else None)

# %%
data['Country'] = data.apply(lambda row: l5.get(row['Brand'], np.nan) if pd.isna(row['Country']) else row['Country'], axis=1)
# Out:
# <ipython-input-324-8161ba19cb5c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Country'] = data.apply(lambda row: l5.get(row['Brand'], np.nan) if pd.isna(row['Country']) else row['Country'], axis=1)

# %%
data=data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 910 entries, 0 to 977
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            910 non-null    object
#  1   Gender_category  910 non-null    object
#  2   Category         910 non-null    category
#  3   Price (₹)        910 non-null    float64
#  4   Discount (%)     910 non-null    float32
#  5   Rating           910 non-null    float32
#  6   Sales Count      910 non-null    int32
#  7   Country          910 non-null    category
#  8   Water Resistant  910 non-null    category
#  9   Gender           910 non-null    object
# dtypes: category(3), float32(2), float64(1), int32(1), object(3)
# memory usage: 49.6+ KB

# %%
data['Country']=data['Country'].astype('category')
# Out:
# <ipython-input-332-8175ff808236>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Country']=data['Country'].astype('category')

# %%
data['Water Resistant']=data['Water Resistant'].astype('category')
# Out:
# <ipython-input-334-033933ecbb5b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Water Resistant']=data['Water Resistant'].astype('category')

# %%
data.rename(columns={' Gender_category':'Gender_category'},inplace=True)
# Out:
# <ipython-input-341-0ad5baed1625>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.rename(columns={' Gender_category':'Gender_category'},inplace=True)

# %%
data['Gender_category']=data['Gender_category'].str.rstrip("'s")
# Out:
# <ipython-input-342-ff6d5dc1378a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gender_category']=data['Gender_category'].str.rstrip("'s")

# %%
data.Gender_category.unique()
# Out:
# array(['women', 'men', 'girl', 'unisex', 'boy'], dtype=object)

# %%
data['Gender']=data.apply(lambda row: 'female' if row['Gender_category'] in ['women','girl']
                                      else 'male' if row['Gender_category'] in ['men','boy']
                                      else 'unisex',axis=1)
# Out:
# <ipython-input-349-cd7973ae4427>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gender']=data.apply(lambda row: 'female' if row['Gender_category'] in ['women','girl']

# %%
data
# Out:
#         Brand Gender_category   Category  Price (₹)  Discount (%)  Rating  \
# 0        Bata           women     sandal      429.0          39.0     4.0
# 1       SPARX             men     sandal      629.0          37.0     4.0
# 2          XE           women       heel      699.0          72.0     4.0
# 3    Centrino             men  flip-flop      769.0          67.0     3.6
# 4       Sparx             men    slipper      279.0          20.0     4.1
# ..        ...             ...        ...        ...           ...     ...
# 973     egoss             men       shoe     3320.0           5.0     4.1
# 974    Clarks             men       shoe     4249.0          29.0     4.0
# 975       Red             men       shoe     2875.0          10.0     3.8
# 976    ANDUNE             men       shoe     2499.0          11.0     3.5
# 977      Bata             men       shoe     2180.0           5.0     3.9
#
#      Sales Count Country Water Resistant  Gender
# ...

# %%
data.to_csv('amazon_footwear_data_maindata_cleaned.csv',index=False)

# %%
import pandas as pd

# %%
data=pd.read_csv(rf"/content/amazon_footwear_data_maindata_cleaned.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 910 entries, 0 to 909
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            910 non-null    object
#  1   Gender_category  910 non-null    object
#  2   Category         910 non-null    object
#  3   Price (₹)        910 non-null    float64
#  4   Discount (%)     910 non-null    float64
#  5   Rating           910 non-null    float64
#  6   Sales Count      910 non-null    int64
#  7   Country          910 non-null    object
#  8   Water Resistant  910 non-null    object
#  9   Gender           910 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 71.2+ KB

# %%
data.Brand.unique()
# Out:
# array(['Bata', 'SPARX', 'XE', 'Centrino', 'Sparx', 'Shoetopia',
#        'KazarMax', 'HEALTH', 'SilverArrow', 'Hush', 'Mochi', 'LUVFEET',
#        'DOCTOR', 'Bacca', 'FLITE', 'Crocs', 'Marc', 'Ortho', 'Neeman',
#        'CASSIEY', 'Metro', 'FAUSTO', 'SVAAR', 'BATA', 'TRASE', 'Dr',
#        'Carlton', 'SCHOLL', 'DRUNKEN', 'ORTHO', 'Scholl', 'Woodland',
#        'ASIAN', 'adidas', 'Van', 'LOVEHUSH', 'GLAMSTREET', 'Hygear',
#        'CANVI', 'AADI', 'DFR', 'Sandak', 'Yellow', 'Columbia', 'Puma',
#        'Liberty', 'ABROS', 'Leepeeter', 'ARAMISH', 'Skechers', 'FEROC',
#        'TrueYarn', 'Power', 'Rising', 'ASICS', 'Campus', 'SHOERELLA',
#        'HITZ', 'Kids', 'Auserio', 'crocs', 'FILA', 'Neoz', 'Elle',
#        'Disney', 'Lancer', 'tresmode', 'Smart', 'STEPIZIA', 'BKRT',
#        'BELLA', 'Bubblegummers', 'Yash', 'HEIGHTEN', 'V', 'Richmen',
#        'AROOM', 'HD', 'Luxyfeel', 'Wolvesden', 'BERSACHE', 'DR',
#        'doubleu', 'VIL', 'WALKAROO', 'LANCER', 'ANNTS', 'San', 'Ajanta',
# ...
