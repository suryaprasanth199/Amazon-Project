# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(rf'/content/amazon_footwear_data_maindata_cleaned.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 910 entries, 0 to 909
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            910 non-null    object
#  1   Gender_category  910 non-null    object
#  2   Category         910 non-null    object
#  3   Price (₹)        910 non-null    float64
#  4   Discount (%)     910 non-null    float64
#  5   Rating           910 non-null    float64
#  6   Sales Count      910 non-null    int64
#  7   Country          910 non-null    object
#  8   Water Resistant  910 non-null    object
#  9   Gender           910 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 71.2+ KB

# %%
data['Gender_category']=data['Gender_category'].astype('category')
data['Category']=data['Category'].astype('category')
data['Price (₹)']=data['Price (₹)'].astype('float32')
data['Discount (%)']=data['Discount (%)'].astype('float32')
data['Rating']=data['Rating'].astype('float32')
data['Sales Count']=data['Sales Count'].astype('int32')
data['Country']=data['Country'].astype('category')
data['Water Resistant']=data['Water Resistant'].astype('category')
data['Gender']=data['Gender'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 910 entries, 0 to 909
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            910 non-null    object
#  1   Gender_category  910 non-null    category
#  2   Category         910 non-null    category
#  3   Price (₹)        910 non-null    float32
#  4   Discount (%)     910 non-null    float32
#  5   Rating           910 non-null    float32
#  6   Sales Count      910 non-null    int32
#  7   Country          910 non-null    category
#  8   Water Resistant  910 non-null    category
#  9   Gender           910 non-null    category
# dtypes: category(5), float32(3), int32(1), object(1)
# memory usage: 26.9+ KB

# %%
data.head()
# Out:
#       Brand Gender_category   Category  Price (₹)  Discount (%)  Rating  \
# 0      Bata           women     sandal      429.0          39.0     4.0
# 1     SPARX             men     sandal      629.0          37.0     4.0
# 2        XE           women       heel      699.0          72.0     4.0
# 3  Centrino             men  flip-flop      769.0          67.0     3.6
# 4     Sparx             men    slipper      279.0          20.0     4.1
#
#    Sales Count Country Water Resistant  Gender  totalsalesAmount
# 0          500   India              NO  female          214500.0
# 1          800   India              NO    male          503200.0
# 2           50   India              NO  female           34950.0
# 3            0   India              NO    male               0.0
# 4            1   India              NO    male             279.0

# %%
topbrands1=data.groupby('Brand')['Sales Count'].agg('sum').sort_values(ascending=False).head(10)

# %%
topbrands.plot(x='Category',y='totalsalesAmount',kind='bar',figsize=(10,5))
# Out:
# <Axes: xlabel='Brand'>

# %%
category_sales=data.groupby('Category')['totalsalesAmount'].agg('sum').sort_values(ascending=False)
# Out:
# <ipython-input-25-bc08a428b3e4>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   category_sales=data.groupby('Category')['totalsalesAmount'].agg('sum').sort_values(ascending=False)

# %%
category_sales.plot(x='Category',y='totalsalesAmount',kind='bar',figsize=(10,5))
# Out:
# <Axes: xlabel='Category'>

# %%
data1=pd.read_csv(rf'/content/Jobs1.csv')
data2=pd.read_csv(rf'/content/Just a moment.csv')
data3=pd.read_csv(rf'/content/software engineer.csv')

# %%
df=pd.concat([data1,data2,data3])

# %%
df.drop(columns=['jobcard_showmorebutton_q9inv'],inplace=True)

# %%
df.Label.fillna('Apply on Company Link',inplace=True)

# %%
df = df.rename(columns={"Title": "Job Title", "Name": "Company Name",'ratingsinglestar_ratingtext_xenmu':'Company Ratings','Salary1':'Salary Est','Label':'Apply Type','Description2':'Skills','jobcard_listingage_jjsuc':'jobcard_listing_age'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15482 entries, 0 to 737
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Job Title            15482 non-null  object
#  1   Company Name         15482 non-null  object
#  2   Company Ratings      11052 non-null  float64
#  3   Location             15481 non-null  object
#  4   Salary               10538 non-null  object
#  5   Salary Est           10538 non-null  object
#  6   Description          15467 non-null  object
#  7   Apply Type           15482 non-null  object
#  8   Skills               14794 non-null  object
#  9   jobcard_listing_age  15482 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.3+ MB

# %%
df.head(10)
# Out:
#                                            Job Title             Company Name  \
# 0  Data Analyst, Predictive Analytics, India- X D...  Boston Consulting Group
# 1                               Analyst-Control Mgmt                     Amex
# 2                               Senior Analyst - RCM                    Optum
# 3                      AP Client Team Senior Analyst  Boston Consulting Group
# 4  Supply Chain Transformation - Performance Analyst                BP Energy
# 5                                Data Analyst Intern                Labmentix
# 6  University Admissions Data Analyst - Remote / ...           Yellow Chapter
# 7                                       Data Analyst          Hewlett Packard
# 8  Remote Data Engineering & Insights Analyst Intern        Minimal Edge Tech
# 9                                Data Analyst - GCSS                  Whatfix
#
#    Company Ratings   Location                       Salary        Salary Est  \
# ...

# %%
df.to_csv('finaldata.csv',index=False)
